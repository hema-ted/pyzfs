# %%
from pyzfs.common.wfc.qboxloader import QboxWavefunctionLoader
from pyzfs.zfs.main import ZFSCalculation

# %%
# Construct wavefunction loader
wfcloader = QboxWavefunctionLoader(filename='o2.xml')
# Out:
# QboxWavefunctionLoader: scanning current working directory "/home/mahe/Midway/scratch/code-test/pyzfs/examples/o2_qbox_xml"...
#
# Reading wavefunction from file o2.xml
#    nuwfcs = 7, ndwfcs = 5, nwfcs = 12
#      spin = up     band = 1     file = o2.xml
#      spin = up     band = 2     file = o2.xml
#      spin = up     band = 3     file = o2.xml
#      spin = up     band = 4     file = o2.xml
#      spin = up     band = 5     file = o2.xml
#      spin = up     band = 6     file = o2.xml
#      spin = up     band = 7     file = o2.xml
#      spin = down     band = 1     file = o2.xml
#      spin = down     band = 2     file = o2.xml
#      spin = down     band = 3     file = o2.xml
#      spin = down     band = 4     file = o2.xml
#      spin = down     band = 5     file = o2.xml
#
# System Overview:
#   Cell:
# {   'G1': array([0.665, 0.   , 0.   ]),
#     'G2': array([0.   , 0.665, 0.   ]),
#     'G3': array([0.   , 0.   , 0.665]),
#     'R1': array([9.449, 0.   , 0.   ]),
#     'R2': array([0.   , 9.449, 0.   ]),
#     'R3': array([0.   , 0.   , 9.449]),
#     'ase_cell': Atoms(symbols='O2', pbc=True, cell=[5.00006941616, 5.00006941616, 5.00006941616]),
#     'omega': 843.5636071689257}
#   FFT Grid:
# {'N': 4096, 'n1': 16, 'n2': 16, 'n3': 16}

# %%
# Construct ZFSCalculation
zfscalc = ZFSCalculation(wfcloader=wfcloader)
# Out:
#
#
#   Zero Field Splitting Calculation Created...
#
#
#     ProcessGrid (square) info:
#     rank -> (irow, icol) mapping:
#     [[0 0]]
#     (irow, icol) -> rank mapping:
#     [[0]]
#     rank  onroot  nrow  ncol  size  irow  icol  is_active  rowcomm_rank  colcomm_rank
#       0    True      1    1    1    0    0    True    0    0
#
#   Creating I array...
#
#     DistributedMatrix info: I
#     irow  icol  nrow  ncol  m  mloc  mstart  mend  n  nloc  nstart  nend  val.shape
#       0    0    1    1    12    12    0    12    12    12    0    12     (12, 12, 6)
#     Index map:
#     [[[ 0 12 12  0 12 12]]]
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.00 MB
#     iorb_rhog_map 0.00 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 144.84 MB

# %%
# Perform ZFS calculation
zfscalc.solve()
# Out:
#   (process 0) 2 orbitals (16%) loaded in 0.001632s...
#   (process 0) 4 orbitals (33%) loaded in 0.001565s...
#   (process 0) 6 orbitals (50%) loaded in 0.001385s...
#   (process 0) 8 orbitals (66%) loaded in 0.001481s...
#   (process 0) 10 orbitals (83%) loaded in 0.001148s...
#   (process 0) 12 orbitals (100%) loaded in 0.001004s...
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.38 MB
#     iorb_rhog_map 0.00 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 146.66 MB
#
#
#   Computing dipole-dipole interaction tensor in G space...
#
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.38 MB
#     iorb_rhog_map 0.00 MB
#     ddig       0.19 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 147.23 MB
#
#
#   Iterating over pairs...
#
#   (process 0) 1 pairs (1%) computed in 0.000108s...
#   (process 0) 2 pairs (2%) computed in 0.004081s...
#   (process 0) 3 pairs (3%) computed in 0.001550s...
#   (process 0) 4 pairs (5%) computed in 0.001198s...
#   (process 0) 5 pairs (6%) computed in 0.001135s...
#   (process 0) 6 pairs (7%) computed in 0.001224s...
#   (process 0) 7 pairs (8%) computed in 0.001188s...
#   (process 0) 8 pairs (10%) computed in 0.001158s...
#   (process 0) 9 pairs (11%) computed in 0.001276s...
#   (process 0) 10 pairs (12%) computed in 0.001228s...
#   (process 0) 11 pairs (14%) computed in 0.001204s...
#   (process 0) 12 pairs (15%) computed in 0.001202s...
#   (process 0) 13 pairs (16%) computed in 0.000065s...
#   (process 0) 14 pairs (17%) computed in 0.001016s...
#   (process 0) 15 pairs (19%) computed in 0.000918s...
#   (process 0) 16 pairs (20%) computed in 0.000889s...
#   (process 0) 17 pairs (21%) computed in 0.000922s...
#   (process 0) 18 pairs (23%) computed in 0.001162s...
#   (process 0) 19 pairs (24%) computed in 0.001196s...
#   (process 0) 20 pairs (25%) computed in 0.001189s...
#   (process 0) 21 pairs (26%) computed in 0.001333s...
#   (process 0) 22 pairs (28%) computed in 0.001303s...
#   (process 0) 23 pairs (29%) computed in 0.001269s...
#   (process 0) 24 pairs (30%) computed in 0.000065s...
#   (process 0) 25 pairs (32%) computed in 0.001324s...
#   (process 0) 26 pairs (33%) computed in 0.001317s...
#   (process 0) 27 pairs (34%) computed in 0.001362s...
#   (process 0) 28 pairs (35%) computed in 0.001303s...
#   (process 0) 29 pairs (37%) computed in 0.000962s...
#   (process 0) 30 pairs (38%) computed in 0.000917s...
#   (process 0) 31 pairs (39%) computed in 0.000868s...
#   (process 0) 32 pairs (41%) computed in 0.000902s...
#   (process 0) 33 pairs (42%) computed in 0.001342s...
#   (process 0) 34 pairs (43%) computed in 0.000068s...
#   (process 0) 35 pairs (44%) computed in 0.001454s...
#   (process 0) 36 pairs (46%) computed in 0.001345s...
#   (process 0) 37 pairs (47%) computed in 0.001317s...
#   (process 0) 38 pairs (48%) computed in 0.001323s...
#   (process 0) 39 pairs (50%) computed in 0.001335s...
#   (process 0) 40 pairs (51%) computed in 0.001263s...
#   (process 0) 41 pairs (52%) computed in 0.001302s...
#   (process 0) 42 pairs (53%) computed in 0.001261s...
#   (process 0) 43 pairs (55%) computed in 0.000068s...
#   (process 0) 44 pairs (56%) computed in 0.001368s...
#   (process 0) 45 pairs (57%) computed in 0.001249s...
#   (process 0) 46 pairs (58%) computed in 0.001246s...
#   (process 0) 47 pairs (60%) computed in 0.001628s...
#   (process 0) 48 pairs (61%) computed in 0.001570s...
#   (process 0) 49 pairs (62%) computed in 0.001556s...
#   (process 0) 50 pairs (64%) computed in 0.001580s...
#   (process 0) 51 pairs (65%) computed in 0.000086s...
#   (process 0) 52 pairs (66%) computed in 0.001714s...
#   (process 0) 53 pairs (67%) computed in 0.001635s...
#   (process 0) 54 pairs (69%) computed in 0.001564s...
#   (process 0) 55 pairs (70%) computed in 0.001598s...
#   (process 0) 56 pairs (71%) computed in 0.001578s...
#   (process 0) 57 pairs (73%) computed in 0.001583s...
#   (process 0) 58 pairs (74%) computed in 0.000093s...
#   (process 0) 59 pairs (75%) computed in 0.001547s...
#   (process 0) 60 pairs (76%) computed in 0.001487s...
#   (process 0) 61 pairs (78%) computed in 0.001534s...
#   (process 0) 62 pairs (79%) computed in 0.001607s...
#   (process 0) 63 pairs (80%) computed in 0.001564s...
#   (process 0) 64 pairs (82%) computed in 0.000093s...
#   (process 0) 65 pairs (83%) computed in 0.001610s...
#   (process 0) 66 pairs (84%) computed in 0.001500s...
#   (process 0) 67 pairs (85%) computed in 0.001501s...
#   (process 0) 68 pairs (87%) computed in 0.001513s...
#   (process 0) 69 pairs (88%) computed in 0.000087s...
#   (process 0) 70 pairs (89%) computed in 0.001542s...
#   (process 0) 71 pairs (91%) computed in 0.001504s...
#   (process 0) 72 pairs (92%) computed in 0.001542s...
#   (process 0) 73 pairs (93%) computed in 0.000089s...
#   (process 0) 74 pairs (94%) computed in 0.001539s...
#   (process 0) 75 pairs (96%) computed in 0.001523s...
#   (process 0) 76 pairs (97%) computed in 0.000088s...
#   (process 0) 77 pairs (98%) computed in 0.001614s...
#   (process 0) 78 pairs (100%) computed in 0.000083s...
#
#
#   Total D tensor (MHz):
#   [[-8.355e+03  6.044e-01  2.290e-01]
#    [ 6.044e-01 -8.355e+03  1.242e-01]
#    [ 2.290e-01  1.242e-01  1.671e+04]]
#   D eigenvalues (MHz):
#   [-8355.401 -8354.192 16709.593]
#   D eigenvectors:
#   [ 7.071e-01 -7.071e-01 -2.957e-06]
#   [-7.071e-01 -7.071e-01  9.965e-06]
#   [9.137e-06 4.956e-06 1.000e+00]
#   Dx, Dy, Dz (|Dz| > |Dx| > |Dy|) (MHz):
#    -8355.400765416656 -8354.191867959378 16709.592633375985
#   Scalar D = 25064.39 MHz, E = -0.60 MHz
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.38 MB
#     iorb_rhog_map 0.00 MB
#     ddig       0.19 MB
#     I          0.01 MB
#     Iglobal    0.01 MB
#   Total memory usage (on process 0): 147.91 MB
#
#   Time elapsed for pair iteration: 0s

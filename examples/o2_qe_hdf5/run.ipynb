# %%
from pyzfs.common.wfc.qeh5loader import QEHDF5WavefunctionLoader
from pyzfs.zfs.main import ZFSCalculation

# %%
# Construct wavefunction loader
wfcloader = QEHDF5WavefunctionLoader(fftgrid='wave')
# Out:
# QEHDF5WavefunctionLoader: scanning current working directory "/home/mahe/repositories/pyzfs/examples/o2_qe_hdf5"...
#
#    nuwfcs = 7, ndwfcs = 5, nwfcs = 12
#      spin = up     band = 1     file = wfcup1.hdf5
#      spin = up     band = 2     file = wfcup1.hdf5
#      spin = up     band = 3     file = wfcup1.hdf5
#      spin = up     band = 4     file = wfcup1.hdf5
#      spin = up     band = 5     file = wfcup1.hdf5
#      spin = up     band = 6     file = wfcup1.hdf5
#      spin = up     band = 7     file = wfcup1.hdf5
#      spin = down     band = 1     file = wfcdw1.hdf5
#      spin = down     band = 2     file = wfcdw1.hdf5
#      spin = down     band = 3     file = wfcdw1.hdf5
#      spin = down     band = 4     file = wfcdw1.hdf5
#      spin = down     band = 5     file = wfcdw1.hdf5
#
# System Overview:
#   Cell:
# {   'G1': array([0.665, 0.   , 0.   ]),
#     'G2': array([0.   , 0.665, 0.   ]),
#     'G3': array([0.   , 0.   , 0.665]),
#     'R1': array([9.449, 0.   , 0.   ]),
#     'R2': array([0.   , 9.449, 0.   ]),
#     'R3': array([0.   , 0.   , 9.449]),
#     'ase_cell': Atoms(symbols='', pbc=True, cell=[5.000059375176199, 5.000059375176199, 5.000059375176199]),
#     'omega': 843.5585251245784}
#   FFT Grid:
# {'N': 2197, 'n1': 13, 'n2': 13, 'n3': 13}

# %%
# Construct ZFSCalculation
zfscalc = ZFSCalculation(wfcloader=wfcloader)
# Out:
#
#
#   Zero Field Splitting Calculation Created...
#
#
#     ProcessGrid (square) info:
#     rank -> (irow, icol) mapping:
#     [[0 0]]
#     (irow, icol) -> rank mapping:
#     [[0]]
#     rank  onroot  nrow  ncol  size  irow  icol  is_active  rowcomm_rank  colcomm_rank
#       0    True      1    1    1    0    0    True    0    0
#
#   Creating I array...
#
#     DistributedMatrix info: I
#     irow  icol  nrow  ncol  m  mloc  mstart  mend  n  nloc  nstart  nend  val.shape
#       0    0    1    1    12    12    0    12    12    12    0    12     (12, 12, 6)
#     Index map:
#     [[[ 0 12 12  0 12 12]]]
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.00 MB
#     iorb_rhog_map 0.00 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 147.52 MB

# %%
# Perform ZFS calculation
zfscalc.solve()
# Out:
#
#   QEHDF5WavefunctionLoader: loading orbitals into memory... (memory mode: "critical")
#
#   (process 0) 2 orbitals (16%) loaded in 0.001183s...
#   (process 0) 4 orbitals (33%) loaded in 0.000100s...
#   (process 0) 6 orbitals (50%) loaded in 0.000056s...
#   (process 0) 8 orbitals (66%) loaded in 0.001832s...
#   (process 0) 10 orbitals (83%) loaded in 0.000095s...
#   (process 0) 12 orbitals (100%) loaded in 0.000045s...
#   QEHDF5WavefunctionLoader: root -> first column scattering
#   QEHDF5WavefunctionLoader: first column -> other column bcast
#   QEHDF5WavefunctionLoader: root -> first row scattering
#   QEHDF5WavefunctionLoader: first row -> other row bcast
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.00 MB
#     iorb_rhog_map 0.00 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 151.25 MB
#
#
#   Computing dipole-dipole interaction tensor in G space...
#
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.00 MB
#     iorb_rhog_map 0.00 MB
#     ddig       0.10 MB
#     I          0.01 MB
#   Total memory usage (on process 0): 151.25 MB
#
#
#   Iterating over pairs...
#
#   (process 0) 1 pairs (1%) computed in 0.000041s...
#   (process 0) 2 pairs (2%) computed in 0.003458s...
#   (process 0) 3 pairs (3%) computed in 0.003642s...
#   (process 0) 4 pairs (5%) computed in 0.003020s...
#   (process 0) 5 pairs (6%) computed in 0.002783s...
#   (process 0) 6 pairs (7%) computed in 0.002795s...
#   (process 0) 7 pairs (8%) computed in 0.002926s...
#   (process 0) 8 pairs (10%) computed in 0.002869s...
#   (process 0) 9 pairs (11%) computed in 0.002784s...
#   (process 0) 10 pairs (12%) computed in 0.002739s...
#   (process 0) 11 pairs (14%) computed in 0.002744s...
#   (process 0) 12 pairs (15%) computed in 0.002741s...
#   (process 0) 13 pairs (16%) computed in 0.000048s...
#   (process 0) 14 pairs (17%) computed in 0.002773s...
#   (process 0) 15 pairs (19%) computed in 0.002731s...
#   (process 0) 16 pairs (20%) computed in 0.002700s...
#   (process 0) 17 pairs (21%) computed in 0.002731s...
#   (process 0) 18 pairs (23%) computed in 0.002738s...
#   (process 0) 19 pairs (24%) computed in 0.002699s...
#   (process 0) 20 pairs (25%) computed in 0.002743s...
#   (process 0) 21 pairs (26%) computed in 0.002748s...
#   (process 0) 22 pairs (28%) computed in 0.002700s...
#   (process 0) 23 pairs (29%) computed in 0.002720s...
#   (process 0) 24 pairs (30%) computed in 0.000048s...
#   (process 0) 25 pairs (32%) computed in 0.002774s...
#   (process 0) 26 pairs (33%) computed in 0.002740s...
#   (process 0) 27 pairs (34%) computed in 0.002749s...
#   (process 0) 28 pairs (35%) computed in 0.002733s...
#   (process 0) 29 pairs (37%) computed in 0.002695s...
#   (process 0) 30 pairs (38%) computed in 0.002752s...
#   (process 0) 31 pairs (39%) computed in 0.002741s...
#   (process 0) 32 pairs (41%) computed in 0.002738s...
#   (process 0) 33 pairs (42%) computed in 0.002701s...
#   (process 0) 34 pairs (43%) computed in 0.000047s...
#   (process 0) 35 pairs (44%) computed in 0.002763s...
#   (process 0) 36 pairs (46%) computed in 0.002736s...
#   (process 0) 37 pairs (47%) computed in 0.002704s...
#   (process 0) 38 pairs (48%) computed in 0.002781s...
#   (process 0) 39 pairs (50%) computed in 0.002750s...
#   (process 0) 40 pairs (51%) computed in 0.002700s...
#   (process 0) 41 pairs (52%) computed in 0.002729s...
#   (process 0) 42 pairs (53%) computed in 0.002725s...
#   (process 0) 43 pairs (55%) computed in 0.000048s...
#   (process 0) 44 pairs (56%) computed in 0.002727s...
#   (process 0) 45 pairs (57%) computed in 0.002719s...
#   (process 0) 46 pairs (58%) computed in 0.002735s...
#   (process 0) 47 pairs (60%) computed in 0.002690s...
#   (process 0) 48 pairs (61%) computed in 0.002723s...
#   (process 0) 49 pairs (62%) computed in 0.002716s...
#   (process 0) 50 pairs (64%) computed in 0.002686s...
#   (process 0) 51 pairs (65%) computed in 0.000048s...
#   (process 0) 52 pairs (66%) computed in 0.002808s...
#   (process 0) 53 pairs (67%) computed in 0.002746s...
#   (process 0) 54 pairs (69%) computed in 0.002734s...
#   (process 0) 55 pairs (70%) computed in 0.002689s...
#   (process 0) 56 pairs (71%) computed in 0.002734s...
#   (process 0) 57 pairs (73%) computed in 0.002727s...
#   (process 0) 58 pairs (74%) computed in 0.000048s...
#   (process 0) 59 pairs (75%) computed in 0.002724s...
#   (process 0) 60 pairs (76%) computed in 0.002730s...
#   (process 0) 61 pairs (78%) computed in 0.002715s...
#   (process 0) 62 pairs (79%) computed in 0.002687s...
#   (process 0) 63 pairs (80%) computed in 0.002725s...
#   (process 0) 64 pairs (82%) computed in 0.000048s...
#   (process 0) 65 pairs (83%) computed in 0.002793s...
#   (process 0) 66 pairs (84%) computed in 0.002702s...
#   (process 0) 67 pairs (85%) computed in 0.002725s...
#   (process 0) 68 pairs (87%) computed in 0.002735s...
#   (process 0) 69 pairs (88%) computed in 0.000048s...
#   (process 0) 70 pairs (89%) computed in 0.002733s...
#   (process 0) 71 pairs (91%) computed in 0.002714s...
#   (process 0) 72 pairs (92%) computed in 0.003196s...
#   (process 0) 73 pairs (93%) computed in 0.000057s...
#   (process 0) 74 pairs (94%) computed in 0.002868s...
#   (process 0) 75 pairs (96%) computed in 0.003249s...
#   (process 0) 76 pairs (97%) computed in 0.000083s...
#   (process 0) 77 pairs (98%) computed in 0.003000s...
#   (process 0) 78 pairs (100%) computed in 0.000081s...
#
#
#   Total D tensor (MHz):
#   [[-8.129e+03 -1.133e-02 -9.484e-02]
#    [-1.133e-02 -8.129e+03  6.114e-02]
#    [-9.484e-02  6.114e-02  1.626e+04]]
#   D eigenvalues (MHz):
#   [16257.342 -8128.696 -8128.646]
#   D eigenvectors:
#   [ 3.889e-06 -2.507e-06 -1.000e+00]
#   [9.722e-01 2.342e-01 3.194e-06]
#   [-2.342e-01  9.722e-01 -3.348e-06]
#   Dx, Dy, Dz (|Dz| > |Dx| > |Dy|) (MHz):
#    -8128.695831000502 -8128.646060957794 16257.341891958295
#   Scalar D = 24386.01 MHz, E = -0.02 MHz
#
#   Memory usage (on process 0):
#     iorb_psir_map 0.00 MB
#     iorb_rhog_map 0.00 MB
#     ddig       0.10 MB
#     I          0.01 MB
#     Iglobal    0.01 MB
#   Total memory usage (on process 0): 151.25 MB
#
#   Time elapsed for pair iteration: 0s
